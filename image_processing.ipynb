# %% [markdown]
# <h2> Image processing in python using cv2</h2>

# %%
# Import modules
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import pandas as pd
from google.colab.patches import cv2_imshow

# %%
# Read the image using cv2 imread function
img =cv2.imread("/content/citi.jpeg") # the original coloured image

# %%
#to read the image in grayscale
gray_scale_img =cv2.imread("/content/citi.jpeg", 0) # the original coloured image

# %%
cv2_imshow(gray_scale_img)
# Out:
# <PIL.Image.Image image mode=L size=286x176 at 0x7FBAFDA412D0>

# %% [markdown]
# # Resizing The Image

# %%
scale_value = 85 # 85% of the original size // the coloured image

# %%
width = int(img.shape[1] * scale_value / 90)
height = int(img.shape[0] * scale_value / 80)
dim = (width, height)
resized=cv2.resize(img,dim)
cv2_imshow(resized)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=270x187 at 0x7FBBAC1B9C10>
# -1

# %%
#the image is now a numpy array 
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
#Image shape
h, w, c = img.shape
print("Height:", h, "Width:", w, "Number of Channels:", c)
# Out:
# Height: 176 Width: 286 Number of Channels: 3

# %%
# image shape can also be extracted as follows
img.shape
# Out:
# (176, 286, 3)

# %%
img.dtype
print(img)
# Out:
# [[[191 100   1]
#   [191 100   1]
#   [189 100   2]
#   ...
#   [142  56  10]
#   [142  56  10]
#   [142  56  10]]
#
#  [[190  99   0]
#   [191 100   1]
#   [189 100   2]
#   ...
#   [142  56  10]
#   [142  56  10]
#   [142  56  10]]
#
#  [[190  99   0]
#   [190  99   0]
#   [188  99   1]
#   ...
#   [142  57   9]
#   [142  57   9]
#   [142  57   9]]
#
#  ...
#
#  [[ 39  92  83]
#   [ 39  94  85]
#   [ 46  99  90]
#   ...
#   [ 32  82  72]
#   [ 38  86  74]
#   [  6  56  44]]
#
#  [[ 32 111 100]
#   [ 24 106  94]
#   [ 19  98  87]
#   ...
#   [ 43 107  95]
#   [ 32  94  80]
#   [  9  74  59]]
#
#  [[ 30 125 111]
#   [ 32 127 113]
#   [ 34 129 115]
#   ...
#   [ 10  80  67]
#   [  9  80  64]
#   [ 28  99  83]]]

# %%
#save img in grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imwrite('citi.jpg', gray)
# Out:
# True

# %%
# Construct a Synthintic image from the img
syn = np.zeros([256, 256])
syn[0:32, :] = 55 
syn[:, :32] = 55 
syn[:, 224:256] = 40 
syn[224:, :] = 40 
syn[32:64, 32:224] = 100 
syn[64:224, 32:64] = 100 
syn[64:224, 192:224] = 100 
syn[192:224, 32:224] = 100 
syn[64:96, 64:192] = 160 
syn[96:192, 64:96] = 160 
syn[96:192, 160:192] = 160 
syn[160:192, 64:192] = 160 
syn[96:160, 96:160] = 220
plt.imshow(syn)
